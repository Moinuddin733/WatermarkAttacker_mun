# %% [markdown]
# <a href="https://colab.research.google.com/github/Moinuddin733/WatermarkAttacker_mun/blob/main/demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""Uncomment the following lines to install the WatermarkAttacker"""
# %cd /
# !git clone https://github.com/XuandongZhao/WatermarkAttacker.git
# %cd WatermarkAttacker
# !pip install -r requirements.txt
# Out:
# /
# Cloning into 'WatermarkAttacker'...
# remote: Enumerating objects: 390, done.
# remote: Counting objects: 100% (101/101), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 390 (delta 65), reused 47 (delta 46), pack-reused 289 (from 1)
# Receiving objects: 100% (390/390), 3.32 MiB | 4.74 MiB/s, done.
# Resolving deltas: 100% (174/174), done.
# /WatermarkAttacker
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (4.57.1)
# Requirement already satisfied: diffusers in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (0.35.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (2.9.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (0.24.0+cu126)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (4.12.0.88)
# Requirement already satisfied: invisible-watermark in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (0.2.0)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (0.25.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (3.10.0)
# Requirement already satisfied: bm3d in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (4.0.3)
# Requirement already satisfied: compressai in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (1.2.6)
# Requirement already satisfied: torch_fidelity in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 11)) (0.3.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 12)) (1.11.0)
# Requirement already satisfied: onnxruntime in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 13)) (1.23.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 1)) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 1)) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 1)) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 1)) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 1)) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 1)) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 1)) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 1)) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 1)) (4.67.1)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.12/dist-packages (from diffusers->-r requirements.txt (line 2)) (8.7.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from diffusers->-r requirements.txt (line 2)) (11.3.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 3)) (3.5.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from invisible-watermark->-r requirements.txt (line 6)) (1.9.0)
# Requirement already satisfied: scipy>=1.11.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->-r requirements.txt (line 7)) (1.16.3)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->-r requirements.txt (line 7)) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->-r requirements.txt (line 7)) (2025.10.16)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->-r requirements.txt (line 7)) (0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 8)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 8)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 8)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 8)) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 8)) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 8)) (2.9.0.post0)
# Requirement already satisfied: bm4d>=4.2.5 in /usr/local/lib/python3.12/dist-packages (from bm3d->-r requirements.txt (line 9)) (4.2.5)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from compressai->-r requirements.txt (line 10)) (0.8.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from compressai->-r requirements.txt (line 10)) (2.2.2)
# Requirement already satisfied: torch-geometric>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from compressai->-r requirements.txt (line 10)) (2.7.0)
# Requirement already satisfied: pytorch-msssim in /usr/local/lib/python3.12/dist-packages (from compressai->-r requirements.txt (line 10)) (1.0.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate->-r requirements.txt (line 12)) (5.9.5)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.12/dist-packages (from onnxruntime->-r requirements.txt (line 13)) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime->-r requirements.txt (line 13)) (25.9.23)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime->-r requirements.txt (line 13)) (5.29.5)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers->-r requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 8)) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->-r requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from torch-geometric>=2.3.0->compressai->-r requirements.txt (line 10)) (3.13.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from torch-geometric>=2.3.0->compressai->-r requirements.txt (line 10)) (3.6.0)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.12/dist-packages (from coloredlogs->onnxruntime->-r requirements.txt (line 13)) (10.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib_metadata->diffusers->-r requirements.txt (line 2)) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->-r requirements.txt (line 3)) (3.0.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->compressai->-r requirements.txt (line 10)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->compressai->-r requirements.txt (line 10)) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers->-r requirements.txt (line 1)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers->-r requirements.txt (line 1)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers->-r requirements.txt (line 1)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers->-r requirements.txt (line 1)) (2025.11.12)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric>=2.3.0->compressai->-r requirements.txt (line 10)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric>=2.3.0->compressai->-r requirements.txt (line 10)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric>=2.3.0->compressai->-r requirements.txt (line 10)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric>=2.3.0->compressai->-r requirements.txt (line 10)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric>=2.3.0->compressai->-r requirements.txt (line 10)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric>=2.3.0->compressai->-r requirements.txt (line 10)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric>=2.3.0->compressai->-r requirements.txt (line 10)) (1.22.0)

# %%
import sys
import torch
import os
import glob
import numpy as np

from regen_pipe import ReSDPipeline

from utils import eval_psnr_ssim_msssim, bytearray_to_bits
from watermarker import InvisibleWatermarker
from wmattacker import DiffWMAttacker, VAEWMAttacker, JPEGAttacker

# %%
wm_text = 'test'
device = 'cuda:0'
ori_path = 'examples/ori_imgs/'
output_path = 'examples/wm_imgs/'
print_width = 50

# %%
os.makedirs(output_path, exist_ok=True)
ori_img_paths = glob.glob(os.path.join(ori_path, '*.*'))
ori_img_paths = sorted([path for path in ori_img_paths if path.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.gif'))])
print(ori_img_paths)
# Out:
# ['examples/ori_imgs/000000000711.png', 'examples/ori_imgs/000000000776.png', 'examples/ori_imgs/000000000885.png', 'examples/ori_imgs/000000000969.png', 'examples/ori_imgs/000000001089.png', 'examples/ori_imgs/000000001442.png']

# %%
wmarkers = {
    'DwtDct': InvisibleWatermarker(wm_text, 'dwtDct'),
    'DwtDctSvd': InvisibleWatermarker(wm_text, 'dwtDctSvd'),
    'RivaGAN': InvisibleWatermarker(wm_text, 'rivaGan'),
}

# %%
pipe = ReSDPipeline.from_pretrained("lzyvegetable/stable-diffusion-2-1", torch_dtype=torch.float16)
pipe.set_progress_bar_config(disable=True)
pipe.to(device)
print('Finished loading model')
# Out:
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]
# Finished loading model

# %%
attackers = {
    'diff_attacker_60': DiffWMAttacker(pipe, batch_size=5, noise_step=60, captions={}),
    'cheng2020-anchor_3': VAEWMAttacker('cheng2020-anchor', quality=3, metric='mse', device=device),
    'bmshj2018-factorized_3': VAEWMAttacker('bmshj2018-factorized', quality=3, metric='mse', device=device),
    'jpeg_attacker_50': JPEGAttacker(quality=50),
}
# Out:
# Diffuse attack initialized with noise step 60 and use prompt 0

# %%
def add_watermark(wmarker_name, wmarker):
    print('*' * print_width)
    print(f'Watermarking with {wmarker_name}')
    os.makedirs(os.path.join(output_path, wmarker_name + '/noatt'), exist_ok=True)
    for ori_img_path in ori_img_paths:
        img_name = os.path.basename(ori_img_path)
        wmarker.encode(ori_img_path, os.path.join(output_path, wmarker_name + '/noatt', img_name))

for wmarker_name, wmarker in wmarkers.items():
    add_watermark(wmarker_name, wmarker)
print('Finished watermarking')
# Out:
# **************************************************
# Watermarking with DwtDct
# **************************************************
# Watermarking with DwtDctSvd
# **************************************************
# Watermarking with RivaGAN
# Finished watermarking

# %%
import torch, gc

torch.cuda.empty_cache()
gc.collect()

for wmarker_name, wmarker in wmarkers.items():
    for attacker_name, attacker in attackers.items():
        print('*' * print_width)
        print(f'Attacking {wmarker_name} with {attacker_name}')
        wm_img_paths = []
        att_img_paths = []
        os.makedirs(os.path.join(output_path, wmarker_name, attacker_name), exist_ok=True)
        for ori_img_path in ori_img_paths:
            img_name = os.path.basename(ori_img_path)
            wm_img_paths.append(os.path.join(output_path, wmarker_name + '/noatt', img_name))
            att_img_paths.append(os.path.join(output_path, wmarker_name, attacker_name, img_name))
        attackers[attacker_name].attack(wm_img_paths, att_img_paths)

print('Finished attacking')
# Out:
# **************************************************
# Attacking DwtDct with diff_attacker_60
# 6it [00:04,  1.36it/s]
# **************************************************
# Attacking DwtDct with cheng2020-anchor_3
# 6it [00:00,  6.88it/s]
# **************************************************
# Attacking DwtDct with bmshj2018-factorized_3
# 6it [00:00,  7.68it/s]
# **************************************************
# Attacking DwtDct with jpeg_attacker_50
# 6it [00:00, 125.12it/s]
# **************************************************
# Attacking DwtDctSvd with diff_attacker_60
# 6it [00:04,  1.39it/s]
# **************************************************
# Attacking DwtDctSvd with cheng2020-anchor_3
# 6it [00:01,  5.46it/s]
# **************************************************
# Attacking DwtDctSvd with bmshj2018-factorized_3
# 6it [00:00,  7.56it/s]
# **************************************************
# Attacking DwtDctSvd with jpeg_attacker_50
# 6it [00:00, 124.47it/s]
# **************************************************
# Attacking RivaGAN with diff_attacker_60
# 6it [00:04,  1.38it/s]
# **************************************************
# Attacking RivaGAN with cheng2020-anchor_3
# 6it [00:00,  6.74it/s]
# **************************************************
# Attacking RivaGAN with bmshj2018-factorized_3
# 6it [00:00,  7.66it/s]
# **************************************************
# Attacking RivaGAN with jpeg_attacker_50
# 6it [00:00, 112.26it/s]
# Finished attacking

# %%
wm_results = {}
for wmarker_name, wmarker in wmarkers.items():
    print('*' * print_width)
    print(f'Watermark: {wmarker_name}')
    wm_successes = []
    wm_psnr_list = []
    wm_ssim_list = []
    wm_msssim_list = []
    for ori_img_path in ori_img_paths:
        img_name = os.path.basename(ori_img_path)
        wm_img_path = os.path.join(output_path, wmarker_name+'/noatt', img_name)
        wm_psnr, wm_ssim, wm_msssim = eval_psnr_ssim_msssim(ori_img_path, wm_img_path)
        wm_psnr_list.append(wm_psnr)
        wm_ssim_list.append(wm_ssim)
        wm_msssim_list.append(wm_msssim)
    wm_results[wmarker_name] = {}
    wm_results[wmarker_name]['wm_psnr'] = np.array(wm_psnr_list).mean()
    wm_results[wmarker_name]['wm_ssim'] = np.array(wm_ssim_list).mean()
    wm_results[wmarker_name]['wm_msssim'] = np.array(wm_msssim_list).mean()

print('Finished evaluating watermarking')
# Out:
# **************************************************
# Watermark: DwtDct
# **************************************************
# Watermark: DwtDctSvd
# **************************************************
# Watermark: RivaGAN
# Finished evaluating watermarking

# %%
wm_results
# Out:
# {'DwtDct': {'wm_psnr': np.float64(39.68427962593789),
#   'wm_ssim': np.float64(0.9798382719357809),
#   'wm_msssim': np.float64(0.9923724134763082)},
#  'DwtDctSvd': {'wm_psnr': np.float64(39.79678248735391),
#   'wm_ssim': np.float64(0.9887041548887888),
#   'wm_msssim': np.float64(0.9908552368481954)},
#  'RivaGAN': {'wm_psnr': np.float64(40.5768330105758),
#   'wm_ssim': np.float64(0.981537659962972),
#   'wm_msssim': np.float64(0.9897827307383219)}}

# %%
detect_wm_results = {}
for wmarker_name, wmarker in wmarkers.items():
    print('*' * print_width)
    print(f'Watermark: {wmarker_name}')
    bit_accs = []
    wm_successes = []
    for ori_img_path in ori_img_paths:
        img_name = os.path.basename(ori_img_path)
        wm_img_path = os.path.join(output_path, wmarker_name+'/noatt', img_name)
        wm_text = wmarkers[wmarker_name].decode(wm_img_path)
        try:
            if type(wm_text) == bytes:
                a = bytearray_to_bits('test'.encode('utf-8'))
                b = bytearray_to_bits(wm_text)
            elif type(wm_text) == str:
                a = bytearray_to_bits('test'.encode('utf-8'))
                b = bytearray_to_bits(wm_text.encode('utf-8'))
            bit_acc = (np.array(a) ==  np.array(b)).mean()
            bit_accs.append(bit_acc)
            if bit_acc > 24/32:
                wm_successes.append(img_name)
        except:
            print('#' * print_width)
            print(f'failed to decode {wm_text}', type(wm_text), len(wm_text))
            pass
    detect_wm_results[wmarker_name] = {}
    detect_wm_results[wmarker_name]['bit_acc'] = np.array(bit_accs).mean()
    detect_wm_results[wmarker_name]['wm_success'] = len(wm_successes) / len(ori_img_paths)
print('Finished evaluating watermarking')
# Out:
# **************************************************
# Watermark: DwtDct
# **************************************************
# Watermark: DwtDctSvd
# **************************************************
# Watermark: RivaGAN
# Finished evaluating watermarking

# %%
detect_wm_results
# Out:
# {'DwtDct': {'bit_acc': np.float64(0.8177083333333334),
#   'wm_success': 0.6666666666666666},
#  'DwtDctSvd': {'bit_acc': np.float64(1.0), 'wm_success': 1.0},
#  'RivaGAN': {'bit_acc': np.float64(1.0), 'wm_success': 1.0}}

# %%
detect_att_results = {}
for wmarker_name, wmarker in wmarkers.items():
    print('*' * print_width)
    print(f'Watermark: {wmarker_name}')
    detect_att_results[wmarker_name] = {}
    for attacker_name, attacker in attackers.items():
        print(f'Attacker: {attacker_name}')
        bit_accs = []
        wm_successes = []
        for ori_img_path in ori_img_paths:
            img_name = os.path.basename(ori_img_path)
            att_img_path = os.path.join(output_path, wmarker_name, attacker_name, img_name)
            att_text = wmarkers[wmarker_name].decode(att_img_path)
            try:
                if type(att_text) == bytes:
                    a = bytearray_to_bits('test'.encode('utf-8'))
                    b = bytearray_to_bits(att_text)
                elif type(att_text) == str:
                    a = bytearray_to_bits('test'.encode('utf-8'))
                    b = bytearray_to_bits(att_text.encode('utf-8'))
                bit_acc = (np.array(a) ==  np.array(b)).mean()
                bit_accs.append(bit_acc)
                if bit_acc > 24/32:
                    wm_successes.append(img_name)
            except:
                print('#' * print_width)
                print(f'failed to decode {wm_text}', type(wm_text), len(wm_text))
                pass
        detect_att_results[wmarker_name][attacker_name] = {}
        detect_att_results[wmarker_name][attacker_name]['bit_acc'] = np.array(bit_accs).mean()
        detect_att_results[wmarker_name][attacker_name]['wm_success'] = len(wm_successes) / len(ori_img_paths)
# Out:
# **************************************************
# Watermark: DwtDct
# Attacker: diff_attacker_60
# Attacker: cheng2020-anchor_3
# Attacker: bmshj2018-factorized_3
# Attacker: jpeg_attacker_50
# **************************************************
# Watermark: DwtDctSvd
# Attacker: diff_attacker_60
# Attacker: cheng2020-anchor_3
# Attacker: bmshj2018-factorized_3
# Attacker: jpeg_attacker_50
# **************************************************
# Watermark: RivaGAN
# Attacker: diff_attacker_60
# Attacker: cheng2020-anchor_3
# Attacker: bmshj2018-factorized_3
# Attacker: jpeg_attacker_50

# %%
detect_att_results
# Out:
# {'DwtDct': {'diff_attacker_60': {'bit_acc': np.float64(0.4947916666666667),
#    'wm_success': 0.0},
#   'cheng2020-anchor_3': {'bit_acc': np.float64(0.4895833333333333),
#    'wm_success': 0.0},
#   'bmshj2018-factorized_3': {'bit_acc': np.float64(0.5052083333333334),
#    'wm_success': 0.0},
#   'jpeg_attacker_50': {'bit_acc': np.float64(0.5260416666666666),
#    'wm_success': 0.0}},
#  'DwtDctSvd': {'diff_attacker_60': {'bit_acc': np.float64(0.5572916666666666),
#    'wm_success': 0.0},
#   'cheng2020-anchor_3': {'bit_acc': np.float64(0.5364583333333334),
#    'wm_success': 0.0},
#   'bmshj2018-factorized_3': {'bit_acc': np.float64(0.5885416666666666),
#    'wm_success': 0.0},
#   'jpeg_attacker_50': {'bit_acc': np.float64(0.8020833333333334),
#    'wm_success': 0.5}},
#  'RivaGAN': {'diff_attacker_60': {'bit_acc': np.float64(0.59375),
#    'wm_success': 0.0},
#   'cheng2020-anchor_3': {'bit_acc': np.float64(0.6510416666666666),
#    'wm_success': 0.0},
#   'bmshj2018-factorized_3': {'bit_acc': np.float64(0.6197916666666666),
#    'wm_success': 0.0},
#   'jpeg_attacker_50': {'bit_acc': np.float64(0.984375), 'wm_success': 1.0}}}

# %%
from IPython.display import Image

# %%
img_id = '000000000711.png'
Image(filename='examples/ori_imgs/'+img_id) # original image

# %%
Image(filename='examples/wm_imgs/DwtDct/noatt/'+img_id) # watermarked image

# %%
Image(filename='examples/wm_imgs/DwtDct/diff_attacker_60/'+img_id) # diffusion attacker
